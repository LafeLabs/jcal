# %%
# load needed python libraries matplotlib, numpy, and scikit-rf
import matplotlib.pyplot as plt
import numpy as np
import skrf as rf
import json

# %%
file_object = open("biaswave.json", "r")
json_string = file_object.read()
file_object.close()
biaswave = json.loads(json_string)

# %%
type(biaswave)
# Out:
# list

# %%
file_object = open("biaswave.js", "w")
file_object.write("biaswave=" + json.dumps(biaswave) + ";")
file_object.close()

# %%
len(biaswave)
# Out:
# 2000
